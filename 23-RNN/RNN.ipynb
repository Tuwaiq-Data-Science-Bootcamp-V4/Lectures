# %% [markdown]
# # Stock Price Prediction
# ## Import Libraries
# - pip install yfinance
# - pip install tensorflow

# %%
import numpy as np
import pandas as pd
import math
import datetime
import yfinance as yf # to use the dataset >> https://pypi.org/project/yfinance/
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import (Dense, Dropout, Activation, Flatten, MaxPooling2D, SimpleRNN)
from sklearn.model_selection import train_test_split
plt.rcParams['figure.dpi'] = 300 # runtime configuration 
plt.rcParams['savefig.dpi'] = 300
# Out:
# 2023-09-05 08:24:30.709291: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Load Data

# %%
ticker = ['AAPL', 'MSFT']
start = datetime.datetime(2019, 1, 1)
end = datetime.datetime(2020, 1 ,1)
stock_prices = yf.download(ticker,start=start, end = end, interval='1d').Close
stock_prices
# Out:
# [*********************100%***********************]  2 of 2 completed
#                  AAPL        MSFT
# Date
# 2019-01-02  39.480000  101.120003
# 2019-01-03  35.547501   97.400002
# 2019-01-04  37.064999  101.930000
# 2019-01-07  36.982498  102.059998
# 2019-01-08  37.687500  102.800003
# ...               ...         ...
# 2019-12-24  71.067497  157.380005
# 2019-12-26  72.477501  158.669998
# 2019-12-27  72.449997  158.960007
# 2019-12-30  72.879997  157.589996
# 2019-12-31  73.412498  157.699997
#
# [252 rows x 2 columns]

# %%
diff_stock_prices = stock_prices.diff().dropna()
## Differencing can help stabilise the mean of a time series by removing changes in the 
## level of a time series and therefore eliminating (or reducing) trend and seasonality.
diff_stock_prices
# Out:
#                 AAPL      MSFT
# Date
# 2019-01-03 -3.932499 -3.720001
# 2019-01-04  1.517498  4.529999
# 2019-01-07 -0.082500  0.129997
# 2019-01-08  0.705002  0.740005
# 2019-01-09  0.639999  1.469994
# ...              ...       ...
# 2019-12-24  0.067497 -0.029999
# 2019-12-26  1.410004  1.289993
# 2019-12-27 -0.027504  0.290009
# 2019-12-30  0.430000 -1.370010
# 2019-12-31  0.532501  0.110001
#
# [251 rows x 2 columns]

# %%
split = int(len(diff_stock_prices['AAPL'].values) * 0.95)
diff_train_aapl = diff_stock_prices['AAPL'].iloc[:split]
diff_test_aapl = diff_stock_prices['AAPL'].iloc[split:]
diff_train_msft = diff_stock_prices['MSFT'].iloc[:split]
diff_test_msft = diff_stock_prices['MSFT'].iloc[split:]

# %%
print(diff_train_aapl.shape)
print(diff_test_aapl.shape)
print(diff_train_msft.shape)
print(diff_test_msft.shape)
# Out:
# (238,)
# (13,)
# (238,)
# (13,)

# %%
n_steps = 13 # number of steps for prediction
n_features = 1 # number of features

# %%
def split_sequence(sequence, n_steps):
    X, y = [], []
    for i in range(len(sequence)):
        end_ix = i + n_steps
        if end_ix > len(sequence) - 1:
            break
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

# %%
# Calling the split_sequence function to define the lookback period
X_aapl, y_aapl = split_sequence(diff_train_aapl, n_steps)

# %%
print(X_aapl.shape)
print(y_aapl.shape)
# Out:
# (225, 13)
# (225,)

# %%
# just for more explenation
X_aapl2 = pd.DataFrame(X_aapl)
X_aapl2 ["Target (Y)"] = pd.DataFrame(y_aapl)
X_aapl2.head(5)
# Out:
#           0         1         2         3         4         5         6  \
# 0 -3.932499  1.517498 -0.082500  0.705002  0.639999  0.122501 -0.377502
# 1  1.517498 -0.082500  0.705002  0.639999  0.122501 -0.377502 -0.572498
# 2 -0.082500  0.705002  0.639999  0.122501 -0.377502 -0.572498  0.767502
# 3  0.705002  0.639999  0.122501 -0.377502 -0.572498  0.767502  0.467499
# 4  0.639999  0.122501 -0.377502 -0.572498  0.767502  0.467499  0.230000
#
#           7         8         9        10        11        12  Target (Y)
# 0 -0.572498  0.767502  0.467499  0.230000  0.240002 -0.880001    0.154999
# 1  0.767502  0.467499  0.230000  0.240002 -0.880001  0.154999   -0.305000
# 2  0.467499  0.230000  0.240002 -0.880001  0.154999 -0.305000    1.264999
# 3  0.230000  0.240002 -0.880001  0.154999 -0.305000  1.264999   -0.364998
# 4  0.240002 -0.880001  0.154999 -0.305000  1.264999 -0.364998   -0.405003

# %%
# Reshaping training data into a three-dimensional case
X_aapl = X_aapl.reshape((X_aapl.shape[0], X_aapl.shape[1], n_features)) #rows, past features, columns 
X_aapl.shape
# Out:
# (225, 13, 1)

# %%
X_msft, y_msft = split_sequence(diff_train_msft, n_steps)
X_msft = X_msft.reshape((X_msft.shape[0],  X_msft.shape[1], n_features))

# %%
print(X_msft.shape)
print(y_msft.shape)
# Out:
# (225, 13, 1)
# (225,)

# %% [markdown]
# ## First: RNN

# %% [markdown]
# ### Step#1: Define the Network

# %%
model = Sequential() # Calling a sequential model to run the RNN
# SimpleRNN layer
# We use return_sequences with Stacking RNNs, so that the following RNN layers can have the full sequence as input.
model.add(SimpleRNN(512, activation='relu', input_shape=(n_steps, n_features), return_sequences=True))
model.add(Dropout(0.2)) # this layer to avoid overfitting (rate between 0 and 1.)
# A Dense layer feeds all outputs from the previous layer to all its neurons, 
# each neuron providing one output to the next layer.
model.add(Dense(256, activation = 'relu')) 
model.add(Flatten())
model.add(Dense(1, activation='linear'))
# Out:
# 2023-09-05 08:45:55.487237: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### Step#2: Compile the Model

# %%
model.compile(optimizer='rmsprop', # Root Mean Squared Propagation
              loss='mean_squared_error',
              metrics=['mse'])

# %% [markdown]
# ### Step#3: Fit the Model

# %%
# Fitting the RNN model to Apple’s stock price
history = model.fit(X_aapl, y_aapl, epochs=400, batch_size=150, verbose=2, validation_split = 0.10)
# batch size is a hyperparameter defines the number of samples to work through before updating the model parameters.
# verbose=0 will show you nothing (silent)
# verbose=1 will show you an animated progress bar
# verbose=2 will just mention the number of epoch
# validation_split = (0 to 1). Fraction of the training data to be used as validation data.
# Out:
# Epoch 1/400
# 2/2 - 1s - loss: 0.6409 - mse: 0.6409 - val_loss: 0.4761 - val_mse: 0.4761 - 1s/epoch - 514ms/step
# Epoch 2/400
# 2/2 - 0s - loss: 0.6013 - mse: 0.6013 - val_loss: 0.5392 - val_mse: 0.5392 - 75ms/epoch - 37ms/step
# Epoch 3/400
# 2/2 - 0s - loss: 0.5918 - mse: 0.5918 - val_loss: 0.5104 - val_mse: 0.5104 - 81ms/epoch - 40ms/step
# Epoch 4/400
# 2/2 - 0s - loss: 0.5462 - mse: 0.5462 - val_loss: 0.5285 - val_mse: 0.5285 - 84ms/epoch - 42ms/step
# Epoch 5/400
# 2/2 - 0s - loss: 0.5239 - mse: 0.5239 - val_loss: 0.5589 - val_mse: 0.5589 - 87ms/epoch - 43ms/step
# Epoch 6/400
# 2/2 - 0s - loss: 0.5127 - mse: 0.5127 - val_loss: 0.5505 - val_mse: 0.5505 - 79ms/epoch - 39ms/step
# Epoch 7/400
# 2/2 - 0s - loss: 0.5351 - mse: 0.5351 - val_loss: 0.5898 - val_mse: 0.5898 - 82ms/epoch - 41ms/step
# Epoch 8/400
# 2/2 - 0s - loss: 0.4805 - mse: 0.4805 - val_loss: 0.5544 - val_mse: 0.5544 - 84ms/epoch - 42ms/step
# Epoch 9/400
# 2/2 - 0s - loss: 0.4624 - mse: 0.4624 - val_loss: 0.6575 - val_mse: 0.6575 - 84ms/epoch - 42ms/step
# Epoch 10/400
# 2/2 - 0s - loss: 0.4457 - mse: 0.4457 - val_loss: 0.6643 - val_mse: 0.6643 - 80ms/epoch - 40ms/step
# Epoch 11/400
# 2/2 - 0s - loss: 0.5003 - mse: 0.5003 - val_loss: 0.5474 - val_mse: 0.5474 - 82ms/epoch - 41ms/step
# Epoch 12/400
# 2/2 - 0s - loss: 0.4428 - mse: 0.4428 - val_loss: 0.5920 - val_mse: 0.5920 - 81ms/epoch - 40ms/step
# Epoch 13/400
# 2/2 - 0s - loss: 0.4259 - mse: 0.4259 - val_loss: 0.6114 - val_mse: 0.6114 - 80ms/epoch - 40ms/step
# Epoch 14/400
# 2/2 - 0s - loss: 0.4114 - mse: 0.4114 - val_loss: 0.6231 - val_mse: 0.6231 - 80ms/epoch - 40ms/step
# Epoch 15/400
# 2/2 - 0s - loss: 0.4657 - mse: 0.4657 - val_loss: 0.5704 - val_mse: 0.5704 - 81ms/epoch - 41ms/step
# Epoch 16/400
# 2/2 - 0s - loss: 0.3852 - mse: 0.3852 - val_loss: 0.6061 - val_mse: 0.6061 - 89ms/epoch - 44ms/step
# Epoch 17/400
# 2/2 - 0s - loss: 0.3663 - mse: 0.3663 - val_loss: 0.6541 - val_mse: 0.6541 - 83ms/epoch - 42ms/step
# Epoch 18/400
# 2/2 - 0s - loss: 0.4405 - mse: 0.4405 - val_loss: 0.5537 - val_mse: 0.5537 - 80ms/epoch - 40ms/step
# Epoch 19/400
# 2/2 - 0s - loss: 0.3664 - mse: 0.3664 - val_loss: 0.6977 - val_mse: 0.6977 - 76ms/epoch - 38ms/step
# Epoch 20/400
# 2/2 - 0s - loss: 0.3577 - mse: 0.3577 - val_loss: 0.5830 - val_mse: 0.5830 - 79ms/epoch - 40ms/step
# Epoch 21/400
# 2/2 - 0s - loss: 0.3174 - mse: 0.3174 - val_loss: 0.7128 - val_mse: 0.7128 - 84ms/epoch - 42ms/step
# Epoch 22/400
# 2/2 - 0s - loss: 0.3174 - mse: 0.3174 - val_loss: 0.6674 - val_mse: 0.6674 - 82ms/epoch - 41ms/step
# Epoch 23/400
# 2/2 - 0s - loss: 0.3623 - mse: 0.3623 - val_loss: 0.5687 - val_mse: 0.5687 - 88ms/epoch - 44ms/step
# Epoch 24/400
# 2/2 - 0s - loss: 0.2872 - mse: 0.2872 - val_loss: 0.5906 - val_mse: 0.5906 - 92ms/epoch - 46ms/step
# Epoch 25/400
# 2/2 - 0s - loss: 0.2602 - mse: 0.2602 - val_loss: 0.5259 - val_mse: 0.5259 - 83ms/epoch - 42ms/step
# Epoch 26/400
# 2/2 - 0s - loss: 0.2774 - mse: 0.2774 - val_loss: 0.5550 - val_mse: 0.5550 - 87ms/epoch - 44ms/step
# Epoch 27/400
# 2/2 - 0s - loss: 0.2430 - mse: 0.2430 - val_loss: 0.6674 - val_mse: 0.6674 - 84ms/epoch - 42ms/step
# Epoch 28/400
# 2/2 - 0s - loss: 0.2984 - mse: 0.2984 - val_loss: 0.5657 - val_mse: 0.5657 - 81ms/epoch - 41ms/step
# Epoch 29/400
# 2/2 - 0s - loss: 0.2038 - mse: 0.2038 - val_loss: 0.7354 - val_mse: 0.7354 - 82ms/epoch - 41ms/step
# Epoch 30/400
# 2/2 - 0s - loss: 0.3114 - mse: 0.3114 - val_loss: 0.4997 - val_mse: 0.4997 - 80ms/epoch - 40ms/step
# Epoch 31/400
# 2/2 - 0s - loss: 0.2045 - mse: 0.2045 - val_loss: 0.7686 - val_mse: 0.7686 - 80ms/epoch - 40ms/step
# Epoch 32/400
# 2/2 - 0s - loss: 0.1603 - mse: 0.1603 - val_loss: 0.6668 - val_mse: 0.6668 - 79ms/epoch - 39ms/step
# Epoch 33/400
# 2/2 - 0s - loss: 0.1417 - mse: 0.1417 - val_loss: 0.7912 - val_mse: 0.7912 - 85ms/epoch - 42ms/step
# Epoch 34/400
# 2/2 - 0s - loss: 0.1350 - mse: 0.1350 - val_loss: 0.8631 - val_mse: 0.8631 - 82ms/epoch - 41ms/step
# Epoch 35/400
# 2/2 - 0s - loss: 0.4207 - mse: 0.4207 - val_loss: 0.5197 - val_mse: 0.5197 - 83ms/epoch - 42ms/step
# Epoch 36/400
# 2/2 - 0s - loss: 0.1943 - mse: 0.1943 - val_loss: 0.6091 - val_mse: 0.6091 - 105ms/epoch - 53ms/step
# Epoch 37/400
# 2/2 - 0s - loss: 0.1164 - mse: 0.1164 - val_loss: 0.6879 - val_mse: 0.6879 - 114ms/epoch - 57ms/step
# Epoch 38/400
# 2/2 - 0s - loss: 0.1631 - mse: 0.1631 - val_loss: 0.6628 - val_mse: 0.6628 - 85ms/epoch - 42ms/step
# Epoch 39/400
# 2/2 - 0s - loss: 0.1251 - mse: 0.1251 - val_loss: 0.7040 - val_mse: 0.7040 - 71ms/epoch - 35ms/step
# Epoch 40/400
# 2/2 - 0s - loss: 0.1237 - mse: 0.1237 - val_loss: 0.8116 - val_mse: 0.8116 - 80ms/epoch - 40ms/step
# Epoch 41/400
# 2/2 - 0s - loss: 0.0909 - mse: 0.0909 - val_loss: 0.5827 - val_mse: 0.5827 - 90ms/epoch - 45ms/step
# Epoch 42/400
# 2/2 - 0s - loss: 0.1153 - mse: 0.1153 - val_loss: 0.7169 - val_mse: 0.7169 - 69ms/epoch - 34ms/step
# Epoch 43/400
# 2/2 - 0s - loss: 0.0928 - mse: 0.0928 - val_loss: 0.5525 - val_mse: 0.5525 - 66ms/epoch - 33ms/step
# Epoch 44/400
# 2/2 - 0s - loss: 0.1228 - mse: 0.1228 - val_loss: 0.6808 - val_mse: 0.6808 - 69ms/epoch - 34ms/step
# Epoch 45/400
# 2/2 - 0s - loss: 0.0918 - mse: 0.0918 - val_loss: 0.5806 - val_mse: 0.5806 - 74ms/epoch - 37ms/step
# Epoch 46/400
# 2/2 - 0s - loss: 0.0574 - mse: 0.0574 - val_loss: 0.7449 - val_mse: 0.7449 - 73ms/epoch - 36ms/step
# Epoch 47/400
# 2/2 - 0s - loss: 0.1081 - mse: 0.1081 - val_loss: 0.6141 - val_mse: 0.6141 - 73ms/epoch - 36ms/step
# Epoch 48/400
# 2/2 - 0s - loss: 0.0628 - mse: 0.0628 - val_loss: 0.7478 - val_mse: 0.7478 - 75ms/epoch - 37ms/step
# Epoch 49/400
# 2/2 - 0s - loss: 0.0501 - mse: 0.0501 - val_loss: 0.6332 - val_mse: 0.6332 - 73ms/epoch - 36ms/step
# Epoch 50/400
# 2/2 - 0s - loss: 0.0521 - mse: 0.0521 - val_loss: 0.6761 - val_mse: 0.6761 - 73ms/epoch - 37ms/step
# Epoch 51/400
# 2/2 - 0s - loss: 0.0803 - mse: 0.0803 - val_loss: 0.5496 - val_mse: 0.5496 - 72ms/epoch - 36ms/step
# Epoch 52/400
# 2/2 - 0s - loss: 0.0662 - mse: 0.0662 - val_loss: 0.7179 - val_mse: 0.7179 - 69ms/epoch - 34ms/step
# Epoch 53/400
# 2/2 - 0s - loss: 0.0533 - mse: 0.0533 - val_loss: 0.5562 - val_mse: 0.5562 - 76ms/epoch - 38ms/step
# Epoch 54/400
# 2/2 - 0s - loss: 0.0691 - mse: 0.0691 - val_loss: 0.8625 - val_mse: 0.8625 - 68ms/epoch - 34ms/step
# Epoch 55/400
# 2/2 - 0s - loss: 0.1265 - mse: 0.1265 - val_loss: 0.5011 - val_mse: 0.5011 - 70ms/epoch - 35ms/step
# Epoch 56/400
# 2/2 - 0s - loss: 0.0582 - mse: 0.0582 - val_loss: 0.6405 - val_mse: 0.6405 - 71ms/epoch - 36ms/step
# Epoch 57/400
# 2/2 - 0s - loss: 0.0423 - mse: 0.0423 - val_loss: 0.5760 - val_mse: 0.5760 - 67ms/epoch - 33ms/step
# Epoch 58/400
# 2/2 - 0s - loss: 0.0362 - mse: 0.0362 - val_loss: 0.5885 - val_mse: 0.5885 - 73ms/epoch - 36ms/step
# Epoch 59/400
# 2/2 - 0s - loss: 0.0433 - mse: 0.0433 - val_loss: 0.4818 - val_mse: 0.4818 - 69ms/epoch - 35ms/step
# Epoch 60/400
# 2/2 - 0s - loss: 0.0285 - mse: 0.0285 - val_loss: 0.5995 - val_mse: 0.5995 - 70ms/epoch - 35ms/step
# Epoch 61/400
# 2/2 - 0s - loss: 0.0283 - mse: 0.0283 - val_loss: 0.5268 - val_mse: 0.5268 - 76ms/epoch - 38ms/step
# Epoch 62/400
# 2/2 - 0s - loss: 0.0375 - mse: 0.0375 - val_loss: 0.5873 - val_mse: 0.5873 - 78ms/epoch - 39ms/step
# Epoch 63/400
# 2/2 - 0s - loss: 0.0818 - mse: 0.0818 - val_loss: 0.5652 - val_mse: 0.5652 - 80ms/epoch - 40ms/step
# Epoch 64/400
# 2/2 - 0s - loss: 0.0559 - mse: 0.0559 - val_loss: 0.6841 - val_mse: 0.6841 - 91ms/epoch - 45ms/step
# Epoch 65/400
# 2/2 - 0s - loss: 0.0255 - mse: 0.0255 - val_loss: 0.6139 - val_mse: 0.6139 - 78ms/epoch - 39ms/step
# Epoch 66/400
# 2/2 - 0s - loss: 0.0349 - mse: 0.0349 - val_loss: 0.5982 - val_mse: 0.5982 - 74ms/epoch - 37ms/step
# Epoch 67/400
# 2/2 - 0s - loss: 0.0255 - mse: 0.0255 - val_loss: 0.5810 - val_mse: 0.5810 - 74ms/epoch - 37ms/step
# Epoch 68/400
# 2/2 - 0s - loss: 0.0235 - mse: 0.0235 - val_loss: 0.6271 - val_mse: 0.6271 - 75ms/epoch - 38ms/step
# Epoch 69/400
# 2/2 - 0s - loss: 0.0612 - mse: 0.0612 - val_loss: 0.5204 - val_mse: 0.5204 - 74ms/epoch - 37ms/step
# Epoch 70/400
# 2/2 - 0s - loss: 0.0550 - mse: 0.0550 - val_loss: 0.6344 - val_mse: 0.6344 - 71ms/epoch - 35ms/step
# Epoch 71/400
# 2/2 - 0s - loss: 0.0908 - mse: 0.0908 - val_loss: 0.6848 - val_mse: 0.6848 - 71ms/epoch - 36ms/step
# Epoch 72/400
# 2/2 - 0s - loss: 0.0335 - mse: 0.0335 - val_loss: 0.6424 - val_mse: 0.6424 - 67ms/epoch - 33ms/step
# Epoch 73/400
# 2/2 - 0s - loss: 0.0238 - mse: 0.0238 - val_loss: 0.6020 - val_mse: 0.6020 - 71ms/epoch - 36ms/step
# Epoch 74/400
# 2/2 - 0s - loss: 0.0180 - mse: 0.0180 - val_loss: 0.5693 - val_mse: 0.5693 - 76ms/epoch - 38ms/step
# Epoch 75/400
# 2/2 - 0s - loss: 0.0229 - mse: 0.0229 - val_loss: 0.5278 - val_mse: 0.5278 - 73ms/epoch - 36ms/step
# Epoch 76/400
# 2/2 - 0s - loss: 0.0458 - mse: 0.0458 - val_loss: 0.5917 - val_mse: 0.5917 - 67ms/epoch - 33ms/step
# Epoch 77/400
# 2/2 - 0s - loss: 0.0420 - mse: 0.0420 - val_loss: 0.6778 - val_mse: 0.6778 - 70ms/epoch - 35ms/step
# Epoch 78/400
# 2/2 - 0s - loss: 0.0478 - mse: 0.0478 - val_loss: 0.6422 - val_mse: 0.6422 - 72ms/epoch - 36ms/step
# Epoch 79/400
# 2/2 - 0s - loss: 0.0761 - mse: 0.0761 - val_loss: 0.5465 - val_mse: 0.5465 - 70ms/epoch - 35ms/step
# Epoch 80/400
# 2/2 - 0s - loss: 0.0550 - mse: 0.0550 - val_loss: 0.6341 - val_mse: 0.6341 - 76ms/epoch - 38ms/step
# Epoch 81/400
# 2/2 - 0s - loss: 0.0380 - mse: 0.0380 - val_loss: 0.5698 - val_mse: 0.5698 - 72ms/epoch - 36ms/step
# Epoch 82/400
# 2/2 - 0s - loss: 0.0271 - mse: 0.0271 - val_loss: 0.5519 - val_mse: 0.5519 - 116ms/epoch - 58ms/step
# Epoch 83/400
# 2/2 - 0s - loss: 0.0269 - mse: 0.0269 - val_loss: 0.5699 - val_mse: 0.5699 - 75ms/epoch - 38ms/step
# Epoch 84/400
# 2/2 - 0s - loss: 0.0212 - mse: 0.0212 - val_loss: 0.5965 - val_mse: 0.5965 - 73ms/epoch - 36ms/step
# Epoch 85/400
# 2/2 - 0s - loss: 0.0301 - mse: 0.0301 - val_loss: 0.5608 - val_mse: 0.5608 - 72ms/epoch - 36ms/step
# Epoch 86/400
# 2/2 - 0s - loss: 0.0347 - mse: 0.0347 - val_loss: 0.5661 - val_mse: 0.5661 - 70ms/epoch - 35ms/step
# Epoch 87/400
# 2/2 - 0s - loss: 0.0204 - mse: 0.0204 - val_loss: 0.5428 - val_mse: 0.5428 - 77ms/epoch - 38ms/step
# Epoch 88/400
# 2/2 - 0s - loss: 0.0165 - mse: 0.0165 - val_loss: 0.5060 - val_mse: 0.5060 - 79ms/epoch - 39ms/step
# Epoch 89/400
# 2/2 - 0s - loss: 0.0273 - mse: 0.0273 - val_loss: 0.5882 - val_mse: 0.5882 - 74ms/epoch - 37ms/step
# Epoch 90/400
# 2/2 - 0s - loss: 0.0640 - mse: 0.0640 - val_loss: 0.5673 - val_mse: 0.5673 - 76ms/epoch - 38ms/step
# Epoch 91/400
# 2/2 - 0s - loss: 0.0454 - mse: 0.0454 - val_loss: 0.5349 - val_mse: 0.5349 - 71ms/epoch - 36ms/step
# Epoch 92/400
# 2/2 - 0s - loss: 0.0164 - mse: 0.0164 - val_loss: 0.5881 - val_mse: 0.5881 - 66ms/epoch - 33ms/step
# Epoch 93/400
# 2/2 - 0s - loss: 0.0094 - mse: 0.0094 - val_loss: 0.5364 - val_mse: 0.5364 - 69ms/epoch - 35ms/step
# Epoch 94/400
# 2/2 - 0s - loss: 0.0150 - mse: 0.0150 - val_loss: 0.5368 - val_mse: 0.5368 - 70ms/epoch - 35ms/step
# Epoch 95/400
# 2/2 - 0s - loss: 0.0151 - mse: 0.0151 - val_loss: 0.6349 - val_mse: 0.6349 - 73ms/epoch - 37ms/step
# Epoch 96/400
# 2/2 - 0s - loss: 0.0281 - mse: 0.0281 - val_loss: 0.6807 - val_mse: 0.6807 - 76ms/epoch - 38ms/step
# Epoch 97/400
# 2/2 - 0s - loss: 0.0509 - mse: 0.0509 - val_loss: 0.5518 - val_mse: 0.5518 - 75ms/epoch - 38ms/step
# Epoch 98/400
# 2/2 - 0s - loss: 0.0380 - mse: 0.0380 - val_loss: 0.6913 - val_mse: 0.6913 - 75ms/epoch - 37ms/step
# Epoch 99/400
# 2/2 - 0s - loss: 0.0590 - mse: 0.0590 - val_loss: 0.5395 - val_mse: 0.5395 - 75ms/epoch - 38ms/step
# Epoch 100/400
# 2/2 - 0s - loss: 0.0227 - mse: 0.0227 - val_loss: 0.5295 - val_mse: 0.5295 - 76ms/epoch - 38ms/step
# Epoch 101/400
# 2/2 - 0s - loss: 0.0201 - mse: 0.0201 - val_loss: 0.4997 - val_mse: 0.4997 - 80ms/epoch - 40ms/step
# Epoch 102/400
# 2/2 - 0s - loss: 0.0175 - mse: 0.0175 - val_loss: 0.6600 - val_mse: 0.6600 - 85ms/epoch - 42ms/step
# Epoch 103/400
# 2/2 - 0s - loss: 0.0213 - mse: 0.0213 - val_loss: 0.5268 - val_mse: 0.5268 - 77ms/epoch - 38ms/step
# Epoch 104/400
# 2/2 - 0s - loss: 0.0190 - mse: 0.0190 - val_loss: 0.6496 - val_mse: 0.6496 - 83ms/epoch - 42ms/step
# Epoch 105/400
# 2/2 - 0s - loss: 0.0328 - mse: 0.0328 - val_loss: 0.5663 - val_mse: 0.5663 - 71ms/epoch - 35ms/step
# Epoch 106/400
# 2/2 - 0s - loss: 0.0278 - mse: 0.0278 - val_loss: 0.5386 - val_mse: 0.5386 - 72ms/epoch - 36ms/step
# Epoch 107/400
# 2/2 - 0s - loss: 0.0200 - mse: 0.0200 - val_loss: 0.6038 - val_mse: 0.6038 - 69ms/epoch - 34ms/step
# Epoch 108/400
# 2/2 - 0s - loss: 0.0228 - mse: 0.0228 - val_loss: 0.5746 - val_mse: 0.5746 - 70ms/epoch - 35ms/step
# Epoch 109/400
# 2/2 - 0s - loss: 0.0287 - mse: 0.0287 - val_loss: 0.5758 - val_mse: 0.5758 - 72ms/epoch - 36ms/step
# Epoch 110/400
# 2/2 - 0s - loss: 0.0240 - mse: 0.0240 - val_loss: 0.5530 - val_mse: 0.5530 - 76ms/epoch - 38ms/step
# Epoch 111/400
# 2/2 - 0s - loss: 0.0190 - mse: 0.0190 - val_loss: 0.5340 - val_mse: 0.5340 - 76ms/epoch - 38ms/step
# Epoch 112/400
# 2/2 - 0s - loss: 0.0200 - mse: 0.0200 - val_loss: 0.5977 - val_mse: 0.5977 - 83ms/epoch - 41ms/step
# Epoch 113/400
# 2/2 - 0s - loss: 0.0103 - mse: 0.0103 - val_loss: 0.5608 - val_mse: 0.5608 - 79ms/epoch - 40ms/step
# Epoch 114/400
# 2/2 - 0s - loss: 0.0149 - mse: 0.0149 - val_loss: 0.6001 - val_mse: 0.6001 - 73ms/epoch - 36ms/step
# Epoch 115/400
# 2/2 - 0s - loss: 0.0126 - mse: 0.0126 - val_loss: 0.5397 - val_mse: 0.5397 - 70ms/epoch - 35ms/step
# Epoch 116/400
# 2/2 - 0s - loss: 0.0151 - mse: 0.0151 - val_loss: 0.6119 - val_mse: 0.6119 - 71ms/epoch - 35ms/step
# Epoch 117/400
# 2/2 - 0s - loss: 0.0154 - mse: 0.0154 - val_loss: 0.6170 - val_mse: 0.6170 - 68ms/epoch - 34ms/step
# Epoch 118/400
# 2/2 - 0s - loss: 0.0513 - mse: 0.0513 - val_loss: 0.6010 - val_mse: 0.6010 - 67ms/epoch - 33ms/step
# Epoch 119/400
# 2/2 - 0s - loss: 0.0504 - mse: 0.0504 - val_loss: 0.5804 - val_mse: 0.5804 - 67ms/epoch - 33ms/step
# Epoch 120/400
# 2/2 - 0s - loss: 0.0245 - mse: 0.0245 - val_loss: 0.5442 - val_mse: 0.5442 - 69ms/epoch - 34ms/step
# Epoch 121/400
# 2/2 - 0s - loss: 0.0133 - mse: 0.0133 - val_loss: 0.6732 - val_mse: 0.6732 - 69ms/epoch - 35ms/step
# Epoch 122/400
# 2/2 - 0s - loss: 0.0335 - mse: 0.0335 - val_loss: 0.5936 - val_mse: 0.5936 - 70ms/epoch - 35ms/step
# Epoch 123/400
# 2/2 - 0s - loss: 0.0359 - mse: 0.0359 - val_loss: 0.5677 - val_mse: 0.5677 - 71ms/epoch - 35ms/step
# Epoch 124/400
# 2/2 - 0s - loss: 0.0127 - mse: 0.0127 - val_loss: 0.5190 - val_mse: 0.5190 - 74ms/epoch - 37ms/step
# Epoch 125/400
# 2/2 - 0s - loss: 0.0123 - mse: 0.0123 - val_loss: 0.5602 - val_mse: 0.5602 - 72ms/epoch - 36ms/step
# Epoch 126/400
# 2/2 - 0s - loss: 0.0138 - mse: 0.0138 - val_loss: 0.5661 - val_mse: 0.5661 - 78ms/epoch - 39ms/step
# Epoch 127/400
# 2/2 - 0s - loss: 0.0145 - mse: 0.0145 - val_loss: 0.5562 - val_mse: 0.5562 - 90ms/epoch - 45ms/step
# Epoch 128/400
# 2/2 - 0s - loss: 0.0148 - mse: 0.0148 - val_loss: 0.5290 - val_mse: 0.5290 - 77ms/epoch - 38ms/step
# Epoch 129/400
# 2/2 - 0s - loss: 0.0150 - mse: 0.0150 - val_loss: 0.5279 - val_mse: 0.5279 - 79ms/epoch - 39ms/step
# Epoch 130/400
# 2/2 - 0s - loss: 0.0116 - mse: 0.0116 - val_loss: 0.5533 - val_mse: 0.5533 - 86ms/epoch - 43ms/step
# Epoch 131/400
# 2/2 - 0s - loss: 0.0160 - mse: 0.0160 - val_loss: 0.5695 - val_mse: 0.5695 - 78ms/epoch - 39ms/step
# Epoch 132/400
# 2/2 - 0s - loss: 0.0138 - mse: 0.0138 - val_loss: 0.4769 - val_mse: 0.4769 - 76ms/epoch - 38ms/step
# Epoch 133/400
# 2/2 - 0s - loss: 0.0216 - mse: 0.0216 - val_loss: 0.4943 - val_mse: 0.4943 - 80ms/epoch - 40ms/step
# Epoch 134/400
# 2/2 - 0s - loss: 0.0307 - mse: 0.0307 - val_loss: 0.5763 - val_mse: 0.5763 - 82ms/epoch - 41ms/step
# Epoch 135/400
# 2/2 - 0s - loss: 0.0355 - mse: 0.0355 - val_loss: 0.6412 - val_mse: 0.6412 - 83ms/epoch - 42ms/step
# Epoch 136/400
# 2/2 - 0s - loss: 0.0146 - mse: 0.0146 - val_loss: 0.5601 - val_mse: 0.5601 - 86ms/epoch - 43ms/step
# Epoch 137/400
# 2/2 - 0s - loss: 0.0168 - mse: 0.0168 - val_loss: 0.5250 - val_mse: 0.5250 - 82ms/epoch - 41ms/step
# Epoch 138/400
# 2/2 - 0s - loss: 0.0154 - mse: 0.0154 - val_loss: 0.5677 - val_mse: 0.5677 - 92ms/epoch - 46ms/step
# Epoch 139/400
# 2/2 - 0s - loss: 0.0120 - mse: 0.0120 - val_loss: 0.5653 - val_mse: 0.5653 - 86ms/epoch - 43ms/step
# Epoch 140/400
# 2/2 - 0s - loss: 0.0147 - mse: 0.0147 - val_loss: 0.5683 - val_mse: 0.5683 - 88ms/epoch - 44ms/step
# Epoch 141/400
# 2/2 - 0s - loss: 0.0097 - mse: 0.0097 - val_loss: 0.6057 - val_mse: 0.6057 - 82ms/epoch - 41ms/step
# Epoch 142/400
# 2/2 - 0s - loss: 0.0160 - mse: 0.0160 - val_loss: 0.5124 - val_mse: 0.5124 - 80ms/epoch - 40ms/step
# Epoch 143/400
# 2/2 - 0s - loss: 0.0176 - mse: 0.0176 - val_loss: 0.5664 - val_mse: 0.5664 - 81ms/epoch - 41ms/step
# Epoch 144/400
# 2/2 - 0s - loss: 0.0388 - mse: 0.0388 - val_loss: 0.4851 - val_mse: 0.4851 - 81ms/epoch - 41ms/step
# Epoch 145/400
# 2/2 - 0s - loss: 0.0189 - mse: 0.0189 - val_loss: 0.5137 - val_mse: 0.5137 - 70ms/epoch - 35ms/step
# Epoch 146/400
# 2/2 - 0s - loss: 0.0160 - mse: 0.0160 - val_loss: 0.5202 - val_mse: 0.5202 - 105ms/epoch - 52ms/step
# Epoch 147/400
# 2/2 - 0s - loss: 0.0138 - mse: 0.0138 - val_loss: 0.5176 - val_mse: 0.5176 - 69ms/epoch - 34ms/step
# Epoch 148/400
# 2/2 - 0s - loss: 0.0125 - mse: 0.0125 - val_loss: 0.5389 - val_mse: 0.5389 - 70ms/epoch - 35ms/step
# Epoch 149/400
# 2/2 - 0s - loss: 0.0117 - mse: 0.0117 - val_loss: 0.5336 - val_mse: 0.5336 - 69ms/epoch - 35ms/step
# Epoch 150/400
# 2/2 - 0s - loss: 0.0188 - mse: 0.0188 - val_loss: 0.5659 - val_mse: 0.5659 - 71ms/epoch - 35ms/step
# Epoch 151/400
# 2/2 - 0s - loss: 0.0352 - mse: 0.0352 - val_loss: 0.5336 - val_mse: 0.5336 - 66ms/epoch - 33ms/step
# Epoch 152/400
# 2/2 - 0s - loss: 0.0214 - mse: 0.0214 - val_loss: 0.5594 - val_mse: 0.5594 - 68ms/epoch - 34ms/step
# Epoch 153/400
# 2/2 - 0s - loss: 0.0093 - mse: 0.0093 - val_loss: 0.4960 - val_mse: 0.4960 - 69ms/epoch - 34ms/step
# Epoch 154/400
# 2/2 - 0s - loss: 0.0106 - mse: 0.0106 - val_loss: 0.4832 - val_mse: 0.4832 - 68ms/epoch - 34ms/step
# Epoch 155/400
# 2/2 - 0s - loss: 0.0100 - mse: 0.0100 - val_loss: 0.5668 - val_mse: 0.5668 - 68ms/epoch - 34ms/step
# Epoch 156/400
# 2/2 - 0s - loss: 0.0066 - mse: 0.0066 - val_loss: 0.4817 - val_mse: 0.4817 - 71ms/epoch - 35ms/step
# Epoch 157/400
# 2/2 - 0s - loss: 0.0106 - mse: 0.0106 - val_loss: 0.5034 - val_mse: 0.5034 - 68ms/epoch - 34ms/step
# Epoch 158/400
# 2/2 - 0s - loss: 0.0176 - mse: 0.0176 - val_loss: 0.5778 - val_mse: 0.5778 - 68ms/epoch - 34ms/step
# Epoch 159/400
# 2/2 - 0s - loss: 0.0211 - mse: 0.0211 - val_loss: 0.6004 - val_mse: 0.6004 - 67ms/epoch - 33ms/step
# Epoch 160/400
# 2/2 - 0s - loss: 0.0189 - mse: 0.0189 - val_loss: 0.5267 - val_mse: 0.5267 - 69ms/epoch - 34ms/step
# Epoch 161/400
# 2/2 - 0s - loss: 0.0170 - mse: 0.0170 - val_loss: 0.5609 - val_mse: 0.5609 - 68ms/epoch - 34ms/step
# Epoch 162/400
# 2/2 - 0s - loss: 0.0116 - mse: 0.0116 - val_loss: 0.5470 - val_mse: 0.5470 - 67ms/epoch - 34ms/step
# Epoch 163/400
# 2/2 - 0s - loss: 0.0107 - mse: 0.0107 - val_loss: 0.5292 - val_mse: 0.5292 - 66ms/epoch - 33ms/step
# Epoch 164/400
# 2/2 - 0s - loss: 0.0090 - mse: 0.0090 - val_loss: 0.6273 - val_mse: 0.6273 - 67ms/epoch - 34ms/step
# Epoch 165/400
# 2/2 - 0s - loss: 0.0265 - mse: 0.0265 - val_loss: 0.4993 - val_mse: 0.4993 - 68ms/epoch - 34ms/step
# Epoch 166/400
# 2/2 - 0s - loss: 0.0308 - mse: 0.0308 - val_loss: 0.4686 - val_mse: 0.4686 - 67ms/epoch - 33ms/step
# Epoch 167/400
# 2/2 - 0s - loss: 0.0156 - mse: 0.0156 - val_loss: 0.5302 - val_mse: 0.5302 - 67ms/epoch - 33ms/step
# Epoch 168/400
# 2/2 - 0s - loss: 0.0084 - mse: 0.0084 - val_loss: 0.5145 - val_mse: 0.5145 - 68ms/epoch - 34ms/step
# Epoch 169/400
# 2/2 - 0s - loss: 0.0080 - mse: 0.0080 - val_loss: 0.4750 - val_mse: 0.4750 - 68ms/epoch - 34ms/step
# Epoch 170/400
# 2/2 - 0s - loss: 0.0074 - mse: 0.0074 - val_loss: 0.5184 - val_mse: 0.5184 - 67ms/epoch - 34ms/step
# Epoch 171/400
# 2/2 - 0s - loss: 0.0087 - mse: 0.0087 - val_loss: 0.4902 - val_mse: 0.4902 - 66ms/epoch - 33ms/step
# Epoch 172/400
# 2/2 - 0s - loss: 0.0089 - mse: 0.0089 - val_loss: 0.5816 - val_mse: 0.5816 - 68ms/epoch - 34ms/step
# Epoch 173/400
# 2/2 - 0s - loss: 0.0114 - mse: 0.0114 - val_loss: 0.4560 - val_mse: 0.4560 - 68ms/epoch - 34ms/step
# Epoch 174/400
# 2/2 - 0s - loss: 0.0103 - mse: 0.0103 - val_loss: 0.5821 - val_mse: 0.5821 - 69ms/epoch - 34ms/step
# Epoch 175/400
# 2/2 - 0s - loss: 0.0162 - mse: 0.0162 - val_loss: 0.5146 - val_mse: 0.5146 - 67ms/epoch - 34ms/step
# Epoch 176/400
# 2/2 - 0s - loss: 0.0217 - mse: 0.0217 - val_loss: 0.4938 - val_mse: 0.4938 - 67ms/epoch - 33ms/step
# Epoch 177/400
# 2/2 - 0s - loss: 0.0125 - mse: 0.0125 - val_loss: 0.5817 - val_mse: 0.5817 - 67ms/epoch - 34ms/step
# Epoch 178/400
# 2/2 - 0s - loss: 0.0081 - mse: 0.0081 - val_loss: 0.5149 - val_mse: 0.5149 - 68ms/epoch - 34ms/step
# Epoch 179/400
# 2/2 - 0s - loss: 0.0061 - mse: 0.0061 - val_loss: 0.5407 - val_mse: 0.5407 - 67ms/epoch - 34ms/step
# Epoch 180/400
# 2/2 - 0s - loss: 0.0060 - mse: 0.0060 - val_loss: 0.5537 - val_mse: 0.5537 - 69ms/epoch - 34ms/step
# Epoch 181/400
# 2/2 - 0s - loss: 0.0063 - mse: 0.0063 - val_loss: 0.5165 - val_mse: 0.5165 - 66ms/epoch - 33ms/step
# Epoch 182/400
# 2/2 - 0s - loss: 0.0108 - mse: 0.0108 - val_loss: 0.5970 - val_mse: 0.5970 - 66ms/epoch - 33ms/step
# Epoch 183/400
# 2/2 - 0s - loss: 0.0320 - mse: 0.0320 - val_loss: 0.4881 - val_mse: 0.4881 - 67ms/epoch - 33ms/step
# Epoch 184/400
# 2/2 - 0s - loss: 0.0125 - mse: 0.0125 - val_loss: 0.4882 - val_mse: 0.4882 - 67ms/epoch - 34ms/step
# Epoch 185/400
# 2/2 - 0s - loss: 0.0124 - mse: 0.0124 - val_loss: 0.5540 - val_mse: 0.5540 - 67ms/epoch - 34ms/step
# Epoch 186/400
# 2/2 - 0s - loss: 0.0150 - mse: 0.0150 - val_loss: 0.5757 - val_mse: 0.5757 - 68ms/epoch - 34ms/step
# Epoch 187/400
# 2/2 - 0s - loss: 0.0222 - mse: 0.0222 - val_loss: 0.4523 - val_mse: 0.4523 - 67ms/epoch - 34ms/step
# Epoch 188/400
# 2/2 - 0s - loss: 0.0132 - mse: 0.0132 - val_loss: 0.5552 - val_mse: 0.5552 - 68ms/epoch - 34ms/step
# Epoch 189/400
# 2/2 - 0s - loss: 0.0141 - mse: 0.0141 - val_loss: 0.4723 - val_mse: 0.4723 - 65ms/epoch - 32ms/step
# Epoch 190/400
# 2/2 - 0s - loss: 0.0100 - mse: 0.0100 - val_loss: 0.5337 - val_mse: 0.5337 - 67ms/epoch - 34ms/step
# Epoch 191/400
# 2/2 - 0s - loss: 0.0077 - mse: 0.0077 - val_loss: 0.5375 - val_mse: 0.5375 - 70ms/epoch - 35ms/step
# Epoch 192/400
# 2/2 - 0s - loss: 0.0066 - mse: 0.0066 - val_loss: 0.5187 - val_mse: 0.5187 - 71ms/epoch - 35ms/step
# Epoch 193/400
# 2/2 - 0s - loss: 0.0111 - mse: 0.0111 - val_loss: 0.5430 - val_mse: 0.5430 - 71ms/epoch - 35ms/step
# Epoch 194/400
# 2/2 - 0s - loss: 0.0114 - mse: 0.0114 - val_loss: 0.4808 - val_mse: 0.4808 - 73ms/epoch - 37ms/step
# Epoch 195/400
# 2/2 - 0s - loss: 0.0110 - mse: 0.0110 - val_loss: 0.5343 - val_mse: 0.5343 - 68ms/epoch - 34ms/step
# Epoch 196/400
# 2/2 - 0s - loss: 0.0111 - mse: 0.0111 - val_loss: 0.5079 - val_mse: 0.5079 - 67ms/epoch - 34ms/step
# Epoch 197/400
# 2/2 - 0s - loss: 0.0148 - mse: 0.0148 - val_loss: 0.5298 - val_mse: 0.5298 - 66ms/epoch - 33ms/step
# Epoch 198/400
# 2/2 - 0s - loss: 0.0111 - mse: 0.0111 - val_loss: 0.5305 - val_mse: 0.5305 - 68ms/epoch - 34ms/step
# Epoch 199/400
# 2/2 - 0s - loss: 0.0059 - mse: 0.0059 - val_loss: 0.4957 - val_mse: 0.4957 - 67ms/epoch - 33ms/step
# Epoch 200/400
# 2/2 - 0s - loss: 0.0058 - mse: 0.0058 - val_loss: 0.5345 - val_mse: 0.5345 - 68ms/epoch - 34ms/step
# Epoch 201/400
# 2/2 - 0s - loss: 0.0085 - mse: 0.0085 - val_loss: 0.5139 - val_mse: 0.5139 - 68ms/epoch - 34ms/step
# Epoch 202/400
# 2/2 - 0s - loss: 0.0055 - mse: 0.0055 - val_loss: 0.5087 - val_mse: 0.5087 - 76ms/epoch - 38ms/step
# Epoch 203/400
# 2/2 - 0s - loss: 0.0075 - mse: 0.0075 - val_loss: 0.5205 - val_mse: 0.5205 - 69ms/epoch - 34ms/step
# Epoch 204/400
# 2/2 - 0s - loss: 0.0140 - mse: 0.0140 - val_loss: 0.5528 - val_mse: 0.5528 - 67ms/epoch - 34ms/step
# Epoch 205/400
# 2/2 - 0s - loss: 0.0224 - mse: 0.0224 - val_loss: 0.5548 - val_mse: 0.5548 - 67ms/epoch - 34ms/step
# Epoch 206/400
# 2/2 - 0s - loss: 0.0158 - mse: 0.0158 - val_loss: 0.5061 - val_mse: 0.5061 - 69ms/epoch - 35ms/step
# Epoch 207/400
# 2/2 - 0s - loss: 0.0100 - mse: 0.0100 - val_loss: 0.5575 - val_mse: 0.5575 - 65ms/epoch - 32ms/step
# Epoch 208/400
# 2/2 - 0s - loss: 0.0124 - mse: 0.0124 - val_loss: 0.5272 - val_mse: 0.5272 - 68ms/epoch - 34ms/step
# Epoch 209/400
# 2/2 - 0s - loss: 0.0098 - mse: 0.0098 - val_loss: 0.5341 - val_mse: 0.5341 - 68ms/epoch - 34ms/step
# Epoch 210/400
# 2/2 - 0s - loss: 0.0089 - mse: 0.0089 - val_loss: 0.5347 - val_mse: 0.5347 - 65ms/epoch - 33ms/step
# Epoch 211/400
# 2/2 - 0s - loss: 0.0139 - mse: 0.0139 - val_loss: 0.4763 - val_mse: 0.4763 - 67ms/epoch - 33ms/step
# Epoch 212/400
# 2/2 - 0s - loss: 0.0099 - mse: 0.0099 - val_loss: 0.5308 - val_mse: 0.5308 - 67ms/epoch - 33ms/step
# Epoch 213/400
# 2/2 - 0s - loss: 0.0077 - mse: 0.0077 - val_loss: 0.4559 - val_mse: 0.4559 - 68ms/epoch - 34ms/step
# Epoch 214/400
# 2/2 - 0s - loss: 0.0063 - mse: 0.0063 - val_loss: 0.5979 - val_mse: 0.5979 - 69ms/epoch - 34ms/step
# Epoch 215/400
# 2/2 - 0s - loss: 0.0104 - mse: 0.0104 - val_loss: 0.4698 - val_mse: 0.4698 - 68ms/epoch - 34ms/step
# Epoch 216/400
# 2/2 - 0s - loss: 0.0088 - mse: 0.0088 - val_loss: 0.5432 - val_mse: 0.5432 - 68ms/epoch - 34ms/step
# Epoch 217/400
# 2/2 - 0s - loss: 0.0069 - mse: 0.0069 - val_loss: 0.5098 - val_mse: 0.5098 - 69ms/epoch - 34ms/step
# Epoch 218/400
# 2/2 - 0s - loss: 0.0082 - mse: 0.0082 - val_loss: 0.4877 - val_mse: 0.4877 - 66ms/epoch - 33ms/step
# Epoch 219/400
# 2/2 - 0s - loss: 0.0128 - mse: 0.0128 - val_loss: 0.5903 - val_mse: 0.5903 - 66ms/epoch - 33ms/step
# Epoch 220/400
# 2/2 - 0s - loss: 0.0252 - mse: 0.0252 - val_loss: 0.5271 - val_mse: 0.5271 - 68ms/epoch - 34ms/step
# Epoch 221/400
# 2/2 - 0s - loss: 0.0147 - mse: 0.0147 - val_loss: 0.5180 - val_mse: 0.5180 - 67ms/epoch - 34ms/step
# Epoch 222/400
# 2/2 - 0s - loss: 0.0080 - mse: 0.0080 - val_loss: 0.4902 - val_mse: 0.4902 - 69ms/epoch - 34ms/step
# Epoch 223/400
# 2/2 - 0s - loss: 0.0083 - mse: 0.0083 - val_loss: 0.5506 - val_mse: 0.5506 - 66ms/epoch - 33ms/step
# Epoch 224/400
# 2/2 - 0s - loss: 0.0069 - mse: 0.0069 - val_loss: 0.5432 - val_mse: 0.5432 - 68ms/epoch - 34ms/step
# Epoch 225/400
# 2/2 - 0s - loss: 0.0078 - mse: 0.0078 - val_loss: 0.5552 - val_mse: 0.5552 - 90ms/epoch - 45ms/step
# Epoch 226/400
# 2/2 - 0s - loss: 0.0109 - mse: 0.0109 - val_loss: 0.5455 - val_mse: 0.5455 - 79ms/epoch - 40ms/step
# Epoch 227/400
# 2/2 - 0s - loss: 0.0079 - mse: 0.0079 - val_loss: 0.5479 - val_mse: 0.5479 - 67ms/epoch - 33ms/step
# Epoch 228/400
# 2/2 - 0s - loss: 0.0086 - mse: 0.0086 - val_loss: 0.5555 - val_mse: 0.5555 - 67ms/epoch - 33ms/step
# Epoch 229/400
# 2/2 - 0s - loss: 0.0049 - mse: 0.0049 - val_loss: 0.5294 - val_mse: 0.5294 - 68ms/epoch - 34ms/step
# Epoch 230/400
# 2/2 - 0s - loss: 0.0062 - mse: 0.0062 - val_loss: 0.5354 - val_mse: 0.5354 - 66ms/epoch - 33ms/step
# Epoch 231/400
# 2/2 - 0s - loss: 0.0114 - mse: 0.0114 - val_loss: 0.5074 - val_mse: 0.5074 - 67ms/epoch - 34ms/step
# Epoch 232/400
# 2/2 - 0s - loss: 0.0082 - mse: 0.0082 - val_loss: 0.4876 - val_mse: 0.4876 - 67ms/epoch - 33ms/step
# Epoch 233/400
# 2/2 - 0s - loss: 0.0068 - mse: 0.0068 - val_loss: 0.5158 - val_mse: 0.5158 - 66ms/epoch - 33ms/step
# Epoch 234/400
# 2/2 - 0s - loss: 0.0083 - mse: 0.0083 - val_loss: 0.5199 - val_mse: 0.5199 - 65ms/epoch - 33ms/step
# Epoch 235/400
# 2/2 - 0s - loss: 0.0139 - mse: 0.0139 - val_loss: 0.4981 - val_mse: 0.4981 - 69ms/epoch - 34ms/step
# Epoch 236/400
# 2/2 - 0s - loss: 0.0130 - mse: 0.0130 - val_loss: 0.5596 - val_mse: 0.5596 - 66ms/epoch - 33ms/step
# Epoch 237/400
# 2/2 - 0s - loss: 0.0140 - mse: 0.0140 - val_loss: 0.4993 - val_mse: 0.4993 - 69ms/epoch - 34ms/step
# Epoch 238/400
# 2/2 - 0s - loss: 0.0088 - mse: 0.0088 - val_loss: 0.4907 - val_mse: 0.4907 - 66ms/epoch - 33ms/step
# Epoch 239/400
# 2/2 - 0s - loss: 0.0058 - mse: 0.0058 - val_loss: 0.5166 - val_mse: 0.5166 - 65ms/epoch - 32ms/step
# Epoch 240/400
# 2/2 - 0s - loss: 0.0105 - mse: 0.0105 - val_loss: 0.4583 - val_mse: 0.4583 - 68ms/epoch - 34ms/step
# Epoch 241/400
# 2/2 - 0s - loss: 0.0131 - mse: 0.0131 - val_loss: 0.5084 - val_mse: 0.5084 - 69ms/epoch - 34ms/step
# Epoch 242/400
# 2/2 - 0s - loss: 0.0125 - mse: 0.0125 - val_loss: 0.4583 - val_mse: 0.4583 - 67ms/epoch - 33ms/step
# Epoch 243/400
# 2/2 - 0s - loss: 0.0098 - mse: 0.0098 - val_loss: 0.5011 - val_mse: 0.5011 - 67ms/epoch - 33ms/step
# Epoch 244/400
# 2/2 - 0s - loss: 0.0067 - mse: 0.0067 - val_loss: 0.4863 - val_mse: 0.4863 - 70ms/epoch - 35ms/step
# Epoch 245/400
# 2/2 - 0s - loss: 0.0075 - mse: 0.0075 - val_loss: 0.5018 - val_mse: 0.5018 - 68ms/epoch - 34ms/step
# Epoch 246/400
# 2/2 - 0s - loss: 0.0060 - mse: 0.0060 - val_loss: 0.5121 - val_mse: 0.5121 - 68ms/epoch - 34ms/step
# Epoch 247/400
# 2/2 - 0s - loss: 0.0060 - mse: 0.0060 - val_loss: 0.4690 - val_mse: 0.4690 - 67ms/epoch - 34ms/step
# Epoch 248/400
# 2/2 - 0s - loss: 0.0102 - mse: 0.0102 - val_loss: 0.5104 - val_mse: 0.5104 - 65ms/epoch - 33ms/step
# Epoch 249/400
# 2/2 - 0s - loss: 0.0088 - mse: 0.0088 - val_loss: 0.5061 - val_mse: 0.5061 - 66ms/epoch - 33ms/step
# Epoch 250/400
# 2/2 - 0s - loss: 0.0058 - mse: 0.0058 - val_loss: 0.5409 - val_mse: 0.5409 - 65ms/epoch - 33ms/step
# Epoch 251/400
# 2/2 - 0s - loss: 0.0075 - mse: 0.0075 - val_loss: 0.4925 - val_mse: 0.4925 - 68ms/epoch - 34ms/step
# Epoch 252/400
# 2/2 - 0s - loss: 0.0139 - mse: 0.0139 - val_loss: 0.5816 - val_mse: 0.5816 - 67ms/epoch - 33ms/step
# Epoch 253/400
# 2/2 - 0s - loss: 0.0216 - mse: 0.0216 - val_loss: 0.5352 - val_mse: 0.5352 - 67ms/epoch - 34ms/step
# Epoch 254/400
# 2/2 - 0s - loss: 0.0126 - mse: 0.0126 - val_loss: 0.5262 - val_mse: 0.5262 - 69ms/epoch - 35ms/step
# Epoch 255/400
# 2/2 - 0s - loss: 0.0102 - mse: 0.0102 - val_loss: 0.5432 - val_mse: 0.5432 - 66ms/epoch - 33ms/step
# Epoch 256/400
# 2/2 - 0s - loss: 0.0104 - mse: 0.0104 - val_loss: 0.5119 - val_mse: 0.5119 - 69ms/epoch - 35ms/step
# Epoch 257/400
# 2/2 - 0s - loss: 0.0054 - mse: 0.0054 - val_loss: 0.4927 - val_mse: 0.4927 - 67ms/epoch - 33ms/step
# Epoch 258/400
# 2/2 - 0s - loss: 0.0066 - mse: 0.0066 - val_loss: 0.5167 - val_mse: 0.5167 - 68ms/epoch - 34ms/step
# Epoch 259/400
# 2/2 - 0s - loss: 0.0092 - mse: 0.0092 - val_loss: 0.5277 - val_mse: 0.5277 - 67ms/epoch - 33ms/step
# Epoch 260/400
# 2/2 - 0s - loss: 0.0081 - mse: 0.0081 - val_loss: 0.5159 - val_mse: 0.5159 - 67ms/epoch - 34ms/step
# Epoch 261/400
# 2/2 - 0s - loss: 0.0106 - mse: 0.0106 - val_loss: 0.5025 - val_mse: 0.5025 - 67ms/epoch - 33ms/step
# Epoch 262/400
# 2/2 - 0s - loss: 0.0080 - mse: 0.0080 - val_loss: 0.5048 - val_mse: 0.5048 - 68ms/epoch - 34ms/step
# Epoch 263/400
# 2/2 - 0s - loss: 0.0050 - mse: 0.0050 - val_loss: 0.5222 - val_mse: 0.5222 - 67ms/epoch - 34ms/step
# Epoch 264/400
# 2/2 - 0s - loss: 0.0070 - mse: 0.0070 - val_loss: 0.5075 - val_mse: 0.5075 - 66ms/epoch - 33ms/step
# Epoch 265/400
# 2/2 - 0s - loss: 0.0148 - mse: 0.0148 - val_loss: 0.5100 - val_mse: 0.5100 - 69ms/epoch - 35ms/step
# Epoch 266/400
# 2/2 - 0s - loss: 0.0093 - mse: 0.0093 - val_loss: 0.5390 - val_mse: 0.5390 - 68ms/epoch - 34ms/step
# Epoch 267/400
# 2/2 - 0s - loss: 0.0094 - mse: 0.0094 - val_loss: 0.5203 - val_mse: 0.5203 - 68ms/epoch - 34ms/step
# Epoch 268/400
# 2/2 - 0s - loss: 0.0098 - mse: 0.0098 - val_loss: 0.5390 - val_mse: 0.5390 - 70ms/epoch - 35ms/step
# Epoch 269/400
# 2/2 - 0s - loss: 0.0090 - mse: 0.0090 - val_loss: 0.5248 - val_mse: 0.5248 - 67ms/epoch - 33ms/step
# Epoch 270/400
# 2/2 - 0s - loss: 0.0123 - mse: 0.0123 - val_loss: 0.4972 - val_mse: 0.4972 - 69ms/epoch - 35ms/step
# Epoch 271/400
# 2/2 - 0s - loss: 0.0068 - mse: 0.0068 - val_loss: 0.5186 - val_mse: 0.5186 - 69ms/epoch - 35ms/step
# Epoch 272/400
# 2/2 - 0s - loss: 0.0049 - mse: 0.0049 - val_loss: 0.5469 - val_mse: 0.5469 - 68ms/epoch - 34ms/step
# Epoch 273/400
# 2/2 - 0s - loss: 0.0050 - mse: 0.0050 - val_loss: 0.5353 - val_mse: 0.5353 - 67ms/epoch - 33ms/step
# Epoch 274/400
# 2/2 - 0s - loss: 0.0046 - mse: 0.0046 - val_loss: 0.5497 - val_mse: 0.5497 - 67ms/epoch - 33ms/step
# Epoch 275/400
# 2/2 - 0s - loss: 0.0099 - mse: 0.0099 - val_loss: 0.5343 - val_mse: 0.5343 - 77ms/epoch - 38ms/step
# Epoch 276/400
# 2/2 - 0s - loss: 0.0076 - mse: 0.0076 - val_loss: 0.5165 - val_mse: 0.5165 - 68ms/epoch - 34ms/step
# Epoch 277/400
# 2/2 - 0s - loss: 0.0077 - mse: 0.0077 - val_loss: 0.5302 - val_mse: 0.5302 - 66ms/epoch - 33ms/step
# Epoch 278/400
# 2/2 - 0s - loss: 0.0084 - mse: 0.0084 - val_loss: 0.5029 - val_mse: 0.5029 - 69ms/epoch - 34ms/step
# Epoch 279/400
# 2/2 - 0s - loss: 0.0142 - mse: 0.0142 - val_loss: 0.5165 - val_mse: 0.5165 - 67ms/epoch - 34ms/step
# Epoch 280/400
# 2/2 - 0s - loss: 0.0133 - mse: 0.0133 - val_loss: 0.4684 - val_mse: 0.4684 - 66ms/epoch - 33ms/step
# Epoch 281/400
# 2/2 - 0s - loss: 0.0070 - mse: 0.0070 - val_loss: 0.5189 - val_mse: 0.5189 - 67ms/epoch - 34ms/step
# Epoch 282/400
# 2/2 - 0s - loss: 0.0082 - mse: 0.0082 - val_loss: 0.4875 - val_mse: 0.4875 - 65ms/epoch - 33ms/step
# Epoch 283/400
# 2/2 - 0s - loss: 0.0071 - mse: 0.0071 - val_loss: 0.4627 - val_mse: 0.4627 - 67ms/epoch - 33ms/step
# Epoch 284/400
# 2/2 - 0s - loss: 0.0115 - mse: 0.0115 - val_loss: 0.5164 - val_mse: 0.5164 - 68ms/epoch - 34ms/step
# Epoch 285/400
# 2/2 - 0s - loss: 0.0093 - mse: 0.0093 - val_loss: 0.5185 - val_mse: 0.5185 - 67ms/epoch - 34ms/step
# Epoch 286/400
# 2/2 - 0s - loss: 0.0065 - mse: 0.0065 - val_loss: 0.4932 - val_mse: 0.4932 - 66ms/epoch - 33ms/step
# Epoch 287/400
# 2/2 - 0s - loss: 0.0058 - mse: 0.0058 - val_loss: 0.4975 - val_mse: 0.4975 - 67ms/epoch - 34ms/step
# Epoch 288/400
# 2/2 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.5080 - val_mse: 0.5080 - 69ms/epoch - 35ms/step
# Epoch 289/400
# 2/2 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.4967 - val_mse: 0.4967 - 67ms/epoch - 33ms/step
# Epoch 290/400
# 2/2 - 0s - loss: 0.0060 - mse: 0.0060 - val_loss: 0.4759 - val_mse: 0.4759 - 64ms/epoch - 32ms/step
# Epoch 291/400
# 2/2 - 0s - loss: 0.0052 - mse: 0.0052 - val_loss: 0.5042 - val_mse: 0.5042 - 66ms/epoch - 33ms/step
# Epoch 292/400
# 2/2 - 0s - loss: 0.0064 - mse: 0.0064 - val_loss: 0.4931 - val_mse: 0.4931 - 69ms/epoch - 35ms/step
# Epoch 293/400
# 2/2 - 0s - loss: 0.0074 - mse: 0.0074 - val_loss: 0.5304 - val_mse: 0.5304 - 69ms/epoch - 34ms/step
# Epoch 294/400
# 2/2 - 0s - loss: 0.0062 - mse: 0.0062 - val_loss: 0.4591 - val_mse: 0.4591 - 67ms/epoch - 33ms/step
# Epoch 295/400
# 2/2 - 0s - loss: 0.0051 - mse: 0.0051 - val_loss: 0.4785 - val_mse: 0.4785 - 68ms/epoch - 34ms/step
# Epoch 296/400
# 2/2 - 0s - loss: 0.0051 - mse: 0.0051 - val_loss: 0.4914 - val_mse: 0.4914 - 65ms/epoch - 33ms/step
# Epoch 297/400
# 2/2 - 0s - loss: 0.0117 - mse: 0.0117 - val_loss: 0.5396 - val_mse: 0.5396 - 68ms/epoch - 34ms/step
# Epoch 298/400
# 2/2 - 0s - loss: 0.0157 - mse: 0.0157 - val_loss: 0.5636 - val_mse: 0.5636 - 101ms/epoch - 51ms/step
# Epoch 299/400
# 2/2 - 0s - loss: 0.0129 - mse: 0.0129 - val_loss: 0.4904 - val_mse: 0.4904 - 67ms/epoch - 34ms/step
# Epoch 300/400
# 2/2 - 0s - loss: 0.0102 - mse: 0.0102 - val_loss: 0.5147 - val_mse: 0.5147 - 68ms/epoch - 34ms/step
# Epoch 301/400
# 2/2 - 0s - loss: 0.0054 - mse: 0.0054 - val_loss: 0.5388 - val_mse: 0.5388 - 66ms/epoch - 33ms/step
# Epoch 302/400
# 2/2 - 0s - loss: 0.0059 - mse: 0.0059 - val_loss: 0.5046 - val_mse: 0.5046 - 67ms/epoch - 33ms/step
# Epoch 303/400
# 2/2 - 0s - loss: 0.0077 - mse: 0.0077 - val_loss: 0.4755 - val_mse: 0.4755 - 68ms/epoch - 34ms/step
# Epoch 304/400
# 2/2 - 0s - loss: 0.0065 - mse: 0.0065 - val_loss: 0.4905 - val_mse: 0.4905 - 67ms/epoch - 33ms/step
# Epoch 305/400
# 2/2 - 0s - loss: 0.0057 - mse: 0.0057 - val_loss: 0.5105 - val_mse: 0.5105 - 68ms/epoch - 34ms/step
# Epoch 306/400
# 2/2 - 0s - loss: 0.0057 - mse: 0.0057 - val_loss: 0.5178 - val_mse: 0.5178 - 68ms/epoch - 34ms/step
# Epoch 307/400
# 2/2 - 0s - loss: 0.0052 - mse: 0.0052 - val_loss: 0.5103 - val_mse: 0.5103 - 64ms/epoch - 32ms/step
# Epoch 308/400
# 2/2 - 0s - loss: 0.0049 - mse: 0.0049 - val_loss: 0.5205 - val_mse: 0.5205 - 68ms/epoch - 34ms/step
# Epoch 309/400
# 2/2 - 0s - loss: 0.0048 - mse: 0.0048 - val_loss: 0.5524 - val_mse: 0.5524 - 68ms/epoch - 34ms/step
# Epoch 310/400
# 2/2 - 0s - loss: 0.0053 - mse: 0.0053 - val_loss: 0.5020 - val_mse: 0.5020 - 66ms/epoch - 33ms/step
# Epoch 311/400
# 2/2 - 0s - loss: 0.0038 - mse: 0.0038 - val_loss: 0.5241 - val_mse: 0.5241 - 68ms/epoch - 34ms/step
# Epoch 312/400
# 2/2 - 0s - loss: 0.0037 - mse: 0.0037 - val_loss: 0.5286 - val_mse: 0.5286 - 66ms/epoch - 33ms/step
# Epoch 313/400
# 2/2 - 0s - loss: 0.0103 - mse: 0.0103 - val_loss: 0.5233 - val_mse: 0.5233 - 70ms/epoch - 35ms/step
# Epoch 314/400
# 2/2 - 0s - loss: 0.0140 - mse: 0.0140 - val_loss: 0.5306 - val_mse: 0.5306 - 67ms/epoch - 34ms/step
# Epoch 315/400
# 2/2 - 0s - loss: 0.0095 - mse: 0.0095 - val_loss: 0.5915 - val_mse: 0.5915 - 68ms/epoch - 34ms/step
# Epoch 316/400
# 2/2 - 0s - loss: 0.0173 - mse: 0.0173 - val_loss: 0.5041 - val_mse: 0.5041 - 70ms/epoch - 35ms/step
# Epoch 317/400
# 2/2 - 0s - loss: 0.0067 - mse: 0.0067 - val_loss: 0.5674 - val_mse: 0.5674 - 67ms/epoch - 33ms/step
# Epoch 318/400
# 2/2 - 0s - loss: 0.0064 - mse: 0.0064 - val_loss: 0.5107 - val_mse: 0.5107 - 67ms/epoch - 33ms/step
# Epoch 319/400
# 2/2 - 0s - loss: 0.0082 - mse: 0.0082 - val_loss: 0.5595 - val_mse: 0.5595 - 67ms/epoch - 33ms/step
# Epoch 320/400
# 2/2 - 0s - loss: 0.0088 - mse: 0.0088 - val_loss: 0.5410 - val_mse: 0.5410 - 66ms/epoch - 33ms/step
# Epoch 321/400
# 2/2 - 0s - loss: 0.0106 - mse: 0.0106 - val_loss: 0.5370 - val_mse: 0.5370 - 67ms/epoch - 34ms/step
# Epoch 322/400
# 2/2 - 0s - loss: 0.0062 - mse: 0.0062 - val_loss: 0.5252 - val_mse: 0.5252 - 68ms/epoch - 34ms/step
# Epoch 323/400
# 2/2 - 0s - loss: 0.0089 - mse: 0.0089 - val_loss: 0.4854 - val_mse: 0.4854 - 65ms/epoch - 32ms/step
# Epoch 324/400
# 2/2 - 0s - loss: 0.0078 - mse: 0.0078 - val_loss: 0.4800 - val_mse: 0.4800 - 66ms/epoch - 33ms/step
# Epoch 325/400
# 2/2 - 0s - loss: 0.0052 - mse: 0.0052 - val_loss: 0.5084 - val_mse: 0.5084 - 66ms/epoch - 33ms/step
# Epoch 326/400
# 2/2 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.5181 - val_mse: 0.5181 - 67ms/epoch - 34ms/step
# Epoch 327/400
# 2/2 - 0s - loss: 0.0037 - mse: 0.0037 - val_loss: 0.4938 - val_mse: 0.4938 - 67ms/epoch - 34ms/step
# Epoch 328/400
# 2/2 - 0s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.4897 - val_mse: 0.4897 - 70ms/epoch - 35ms/step
# Epoch 329/400
# 2/2 - 0s - loss: 0.0040 - mse: 0.0040 - val_loss: 0.5024 - val_mse: 0.5024 - 71ms/epoch - 35ms/step
# Epoch 330/400
# 2/2 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.5002 - val_mse: 0.5002 - 70ms/epoch - 35ms/step
# Epoch 331/400
# 2/2 - 0s - loss: 0.0039 - mse: 0.0039 - val_loss: 0.5110 - val_mse: 0.5110 - 69ms/epoch - 34ms/step
# Epoch 332/400
# 2/2 - 0s - loss: 0.0080 - mse: 0.0080 - val_loss: 0.5182 - val_mse: 0.5182 - 68ms/epoch - 34ms/step
# Epoch 333/400
# 2/2 - 0s - loss: 0.0135 - mse: 0.0135 - val_loss: 0.5506 - val_mse: 0.5506 - 68ms/epoch - 34ms/step
# Epoch 334/400
# 2/2 - 0s - loss: 0.0096 - mse: 0.0096 - val_loss: 0.5570 - val_mse: 0.5570 - 67ms/epoch - 34ms/step
# Epoch 335/400
# 2/2 - 0s - loss: 0.0134 - mse: 0.0134 - val_loss: 0.4574 - val_mse: 0.4574 - 72ms/epoch - 36ms/step
# Epoch 336/400
# 2/2 - 0s - loss: 0.0085 - mse: 0.0085 - val_loss: 0.5182 - val_mse: 0.5182 - 68ms/epoch - 34ms/step
# Epoch 337/400
# 2/2 - 0s - loss: 0.0040 - mse: 0.0040 - val_loss: 0.4890 - val_mse: 0.4890 - 66ms/epoch - 33ms/step
# Epoch 338/400
# 2/2 - 0s - loss: 0.0055 - mse: 0.0055 - val_loss: 0.5213 - val_mse: 0.5213 - 69ms/epoch - 34ms/step
# Epoch 339/400
# 2/2 - 0s - loss: 0.0063 - mse: 0.0063 - val_loss: 0.5747 - val_mse: 0.5747 - 67ms/epoch - 33ms/step
# Epoch 340/400
# 2/2 - 0s - loss: 0.0230 - mse: 0.0230 - val_loss: 0.4960 - val_mse: 0.4960 - 68ms/epoch - 34ms/step
# Epoch 341/400
# 2/2 - 0s - loss: 0.0113 - mse: 0.0113 - val_loss: 0.5223 - val_mse: 0.5223 - 66ms/epoch - 33ms/step
# Epoch 342/400
# 2/2 - 0s - loss: 0.0057 - mse: 0.0057 - val_loss: 0.5159 - val_mse: 0.5159 - 67ms/epoch - 33ms/step
# Epoch 343/400
# 2/2 - 0s - loss: 0.0069 - mse: 0.0069 - val_loss: 0.4838 - val_mse: 0.4838 - 68ms/epoch - 34ms/step
# Epoch 344/400
# 2/2 - 0s - loss: 0.0049 - mse: 0.0049 - val_loss: 0.5051 - val_mse: 0.5051 - 67ms/epoch - 34ms/step
# Epoch 345/400
# 2/2 - 0s - loss: 0.0050 - mse: 0.0050 - val_loss: 0.5060 - val_mse: 0.5060 - 68ms/epoch - 34ms/step
# Epoch 346/400
# 2/2 - 0s - loss: 0.0050 - mse: 0.0050 - val_loss: 0.5007 - val_mse: 0.5007 - 67ms/epoch - 34ms/step
# Epoch 347/400
# 2/2 - 0s - loss: 0.0075 - mse: 0.0075 - val_loss: 0.5003 - val_mse: 0.5003 - 67ms/epoch - 34ms/step
# Epoch 348/400
# 2/2 - 0s - loss: 0.0069 - mse: 0.0069 - val_loss: 0.5317 - val_mse: 0.5317 - 65ms/epoch - 33ms/step
# Epoch 349/400
# 2/2 - 0s - loss: 0.0066 - mse: 0.0066 - val_loss: 0.4749 - val_mse: 0.4749 - 65ms/epoch - 32ms/step
# Epoch 350/400
# 2/2 - 0s - loss: 0.0056 - mse: 0.0056 - val_loss: 0.4800 - val_mse: 0.4800 - 65ms/epoch - 33ms/step
# Epoch 351/400
# 2/2 - 0s - loss: 0.0077 - mse: 0.0077 - val_loss: 0.5007 - val_mse: 0.5007 - 77ms/epoch - 38ms/step
# Epoch 352/400
# 2/2 - 0s - loss: 0.0050 - mse: 0.0050 - val_loss: 0.4911 - val_mse: 0.4911 - 67ms/epoch - 34ms/step
# Epoch 353/400
# 2/2 - 0s - loss: 0.0056 - mse: 0.0056 - val_loss: 0.4947 - val_mse: 0.4947 - 67ms/epoch - 33ms/step
# Epoch 354/400
# 2/2 - 0s - loss: 0.0070 - mse: 0.0070 - val_loss: 0.5072 - val_mse: 0.5072 - 67ms/epoch - 33ms/step
# Epoch 355/400
# 2/2 - 0s - loss: 0.0099 - mse: 0.0099 - val_loss: 0.4935 - val_mse: 0.4935 - 69ms/epoch - 34ms/step
# Epoch 356/400
# 2/2 - 0s - loss: 0.0096 - mse: 0.0096 - val_loss: 0.5092 - val_mse: 0.5092 - 66ms/epoch - 33ms/step
# Epoch 357/400
# 2/2 - 0s - loss: 0.0054 - mse: 0.0054 - val_loss: 0.5177 - val_mse: 0.5177 - 66ms/epoch - 33ms/step
# Epoch 358/400
# 2/2 - 0s - loss: 0.0065 - mse: 0.0065 - val_loss: 0.4812 - val_mse: 0.4812 - 67ms/epoch - 33ms/step
# Epoch 359/400
# 2/2 - 0s - loss: 0.0047 - mse: 0.0047 - val_loss: 0.4874 - val_mse: 0.4874 - 67ms/epoch - 34ms/step
# Epoch 360/400
# 2/2 - 0s - loss: 0.0039 - mse: 0.0039 - val_loss: 0.5394 - val_mse: 0.5394 - 66ms/epoch - 33ms/step
# Epoch 361/400
# 2/2 - 0s - loss: 0.0058 - mse: 0.0058 - val_loss: 0.5039 - val_mse: 0.5039 - 68ms/epoch - 34ms/step
# Epoch 362/400
# 2/2 - 0s - loss: 0.0091 - mse: 0.0091 - val_loss: 0.4981 - val_mse: 0.4981 - 67ms/epoch - 34ms/step
# Epoch 363/400
# 2/2 - 0s - loss: 0.0091 - mse: 0.0091 - val_loss: 0.5445 - val_mse: 0.5445 - 68ms/epoch - 34ms/step
# Epoch 364/400
# 2/2 - 0s - loss: 0.0055 - mse: 0.0055 - val_loss: 0.4892 - val_mse: 0.4892 - 69ms/epoch - 34ms/step
# Epoch 365/400
# 2/2 - 0s - loss: 0.0034 - mse: 0.0034 - val_loss: 0.4598 - val_mse: 0.4598 - 68ms/epoch - 34ms/step
# Epoch 366/400
# 2/2 - 0s - loss: 0.0037 - mse: 0.0037 - val_loss: 0.5075 - val_mse: 0.5075 - 95ms/epoch - 47ms/step
# Epoch 367/400
# 2/2 - 0s - loss: 0.0038 - mse: 0.0038 - val_loss: 0.5117 - val_mse: 0.5117 - 81ms/epoch - 41ms/step
# Epoch 368/400
# 2/2 - 0s - loss: 0.0058 - mse: 0.0058 - val_loss: 0.4936 - val_mse: 0.4936 - 68ms/epoch - 34ms/step
# Epoch 369/400
# 2/2 - 0s - loss: 0.0101 - mse: 0.0101 - val_loss: 0.4878 - val_mse: 0.4878 - 67ms/epoch - 34ms/step
# Epoch 370/400
# 2/2 - 0s - loss: 0.0089 - mse: 0.0089 - val_loss: 0.4893 - val_mse: 0.4893 - 67ms/epoch - 34ms/step
# Epoch 371/400
# 2/2 - 0s - loss: 0.0052 - mse: 0.0052 - val_loss: 0.4741 - val_mse: 0.4741 - 67ms/epoch - 34ms/step
# Epoch 372/400
# 2/2 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.5026 - val_mse: 0.5026 - 69ms/epoch - 35ms/step
# Epoch 373/400
# 2/2 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.4638 - val_mse: 0.4638 - 66ms/epoch - 33ms/step
# Epoch 374/400
# 2/2 - 0s - loss: 0.0050 - mse: 0.0050 - val_loss: 0.4873 - val_mse: 0.4873 - 67ms/epoch - 33ms/step
# Epoch 375/400
# 2/2 - 0s - loss: 0.0087 - mse: 0.0087 - val_loss: 0.5170 - val_mse: 0.5170 - 68ms/epoch - 34ms/step
# Epoch 376/400
# 2/2 - 0s - loss: 0.0080 - mse: 0.0080 - val_loss: 0.4992 - val_mse: 0.4992 - 67ms/epoch - 34ms/step
# Epoch 377/400
# 2/2 - 0s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.4966 - val_mse: 0.4966 - 69ms/epoch - 34ms/step
# Epoch 378/400
# 2/2 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.5270 - val_mse: 0.5270 - 67ms/epoch - 34ms/step
# Epoch 379/400
# 2/2 - 0s - loss: 0.0055 - mse: 0.0055 - val_loss: 0.4953 - val_mse: 0.4953 - 66ms/epoch - 33ms/step
# Epoch 380/400
# 2/2 - 0s - loss: 0.0039 - mse: 0.0039 - val_loss: 0.4891 - val_mse: 0.4891 - 67ms/epoch - 33ms/step
# Epoch 381/400
# 2/2 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.5093 - val_mse: 0.5093 - 68ms/epoch - 34ms/step
# Epoch 382/400
# 2/2 - 0s - loss: 0.0049 - mse: 0.0049 - val_loss: 0.5397 - val_mse: 0.5397 - 67ms/epoch - 33ms/step
# Epoch 383/400
# 2/2 - 0s - loss: 0.0112 - mse: 0.0112 - val_loss: 0.5001 - val_mse: 0.5001 - 68ms/epoch - 34ms/step
# Epoch 384/400
# 2/2 - 0s - loss: 0.0139 - mse: 0.0139 - val_loss: 0.5093 - val_mse: 0.5093 - 68ms/epoch - 34ms/step
# Epoch 385/400
# 2/2 - 0s - loss: 0.0073 - mse: 0.0073 - val_loss: 0.5090 - val_mse: 0.5090 - 68ms/epoch - 34ms/step
# Epoch 386/400
# 2/2 - 0s - loss: 0.0089 - mse: 0.0089 - val_loss: 0.4967 - val_mse: 0.4967 - 68ms/epoch - 34ms/step
# Epoch 387/400
# 2/2 - 0s - loss: 0.0138 - mse: 0.0138 - val_loss: 0.4890 - val_mse: 0.4890 - 68ms/epoch - 34ms/step
# Epoch 388/400
# 2/2 - 0s - loss: 0.0050 - mse: 0.0050 - val_loss: 0.4807 - val_mse: 0.4807 - 67ms/epoch - 34ms/step
# Epoch 389/400
# 2/2 - 0s - loss: 0.0037 - mse: 0.0037 - val_loss: 0.4876 - val_mse: 0.4876 - 69ms/epoch - 34ms/step
# Epoch 390/400
# 2/2 - 0s - loss: 0.0033 - mse: 0.0033 - val_loss: 0.4912 - val_mse: 0.4912 - 67ms/epoch - 33ms/step
# Epoch 391/400
# 2/2 - 0s - loss: 0.0032 - mse: 0.0032 - val_loss: 0.5137 - val_mse: 0.5137 - 66ms/epoch - 33ms/step
# Epoch 392/400
# 2/2 - 0s - loss: 0.0052 - mse: 0.0052 - val_loss: 0.5403 - val_mse: 0.5403 - 67ms/epoch - 34ms/step
# Epoch 393/400
# 2/2 - 0s - loss: 0.0073 - mse: 0.0073 - val_loss: 0.4938 - val_mse: 0.4938 - 67ms/epoch - 34ms/step
# Epoch 394/400
# 2/2 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.4701 - val_mse: 0.4701 - 68ms/epoch - 34ms/step
# Epoch 395/400
# 2/2 - 0s - loss: 0.0038 - mse: 0.0038 - val_loss: 0.4963 - val_mse: 0.4963 - 66ms/epoch - 33ms/step
# Epoch 396/400
# 2/2 - 0s - loss: 0.0029 - mse: 0.0029 - val_loss: 0.5065 - val_mse: 0.5065 - 68ms/epoch - 34ms/step
# Epoch 397/400
# 2/2 - 0s - loss: 0.0038 - mse: 0.0038 - val_loss: 0.4678 - val_mse: 0.4678 - 68ms/epoch - 34ms/step
# Epoch 398/400
# 2/2 - 0s - loss: 0.0084 - mse: 0.0084 - val_loss: 0.5164 - val_mse: 0.5164 - 69ms/epoch - 34ms/step
# Epoch 399/400
# 2/2 - 0s - loss: 0.0057 - mse: 0.0057 - val_loss: 0.5007 - val_mse: 0.5007 - 67ms/epoch - 33ms/step
# Epoch 400/400
# 2/2 - 0s - loss: 0.0051 - mse: 0.0051 - val_loss: 0.4899 - val_mse: 0.4899 - 66ms/epoch - 33ms/step

# %%
# Defining the starting point of the prediction for Apple
start = X_aapl[X_aapl.shape[0] - n_steps] # X_aapl[212] >> 225-13
x_input = start
x_input = x_input.reshape((1, n_steps, n_features)) # (13, 1) to (1, 13, 1)

# %%
print(x_input.shape)
x_input
# Out:
# (1, 13, 1)
# array([[[-0.09249878],
#         [ 0.02749634],
#         [ 0.54750061],
#         [ 0.17750549],
#         [ 0.51499939],
#         [-0.06000519],
#         [ 0.62750244],
#         [-0.45749664],
#         [ 0.77999878],
#         [ 0.33499908],
#         [-0.20249939],
#         [-0.77500153],
#         [-0.29499817]]])

# %%
tempList_aapl = [] # an empty list to store predictions
for i in range(len(diff_test_aapl)): # 13
    x_input = x_input.reshape((1, n_steps, n_features)) # Reshaping the x_input, which is used for prediction
    #print(x_input)
    #print("****")
    yhat = model.predict(x_input, verbose=0) # Running prediction for Apple stock
    #print(yhat)
    #print("****")
    x_input = np.append(x_input, yhat) # Storing yhat into tempList_aapl
    #print(x_input)
    #print("****")
    x_input = x_input[1:] # update x_input to start with the second value in x_input
    #print(x_input)
    #print("****")
    tempList_aapl.append(yhat)
    #print("--------------------------------")

# %%
tempList_aapl
# Out:
# [array([[0.51885766]], dtype=float32),
#  array([[0.67674804]], dtype=float32),
#  array([[0.48201784]], dtype=float32),
#  array([[-0.3652185]], dtype=float32),
#  array([[-0.09448625]], dtype=float32),
#  array([[-1.4604347]], dtype=float32),
#  array([[0.4192895]], dtype=float32),
#  array([[0.40408477]], dtype=float32),
#  array([[0.26937333]], dtype=float32),
#  array([[-0.04353677]], dtype=float32),
#  array([[0.08824278]], dtype=float32),
#  array([[0.4256006]], dtype=float32),
#  array([[-0.29669774]], dtype=float32)]

# %%
history = model.fit(X_msft, y_msft, epochs=400, batch_size=150, verbose=0, validation_split = 0.10)

# %%
start = X_msft[X_msft.shape[0] - n_steps]
x_input = start
x_input = x_input.reshape((1, n_steps, n_features))

# %%
tempList_msft = []
for i in range(len(diff_test_msft)):
    x_input = x_input.reshape((1, n_steps, n_features))
    yhat = model.predict(x_input, verbose=0)
    x_input = np.append(x_input, yhat)
    x_input = x_input[1:]
    tempList_msft.append(yhat)

# %%
#  visualization
fig, ax = plt.subplots(2,1, figsize=(18,15))
ax[0].plot(diff_test_aapl, label='Actual Stock Price', linestyle='--')
ax[0].plot(diff_test_aapl.index, np.array(tempList_aapl).flatten(), linestyle='solid', label="Prediction")
ax[0].set_title('Predicted Stock Price-Apple')
ax[0].legend(loc='best')

ax[1].plot(diff_test_msft, label='Actual Stock Price', linestyle='--')
ax[1].plot(diff_test_msft.index,np.array(tempList_msft).flatten(), linestyle='solid', label="Prediction")
ax[1].set_title('Predicted Stock Price-Microsoft')
ax[1].legend(loc='best')


for ax in ax.flat:
    ax.set(xlabel='Date', ylabel='Differenced Price')
plt.show()

# %% [markdown]
# ## Second: LSTM

# %%
from tensorflow.keras.layers import LSTM

# %%
n_steps = 13
n_features = 1
model = Sequential()
model.add(LSTM(512, activation='relu', input_shape=(n_steps, n_features),return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(256,activation='relu'))
model.add(Flatten())
model.add(Dense(1, activation='linear'))

# %%
model.compile(optimizer='rmsprop', loss='mean_squared_error', metrics=['mse'])
history = model.fit(X_aapl, y_aapl, epochs=400, batch_size=150, verbose=0, validation_split = 0.10)

# %%
start = X_aapl[X_aapl.shape[0] - 13]
x_input = start
x_input = x_input.reshape((1, n_steps, n_features))

# %%
tempList_aapl = []
for i in range(len(diff_test_aapl)):
    x_input = x_input.reshape((1, n_steps, n_features))
    yhat = model.predict(x_input, verbose=0)
    x_input = np.append(x_input, yhat)
    x_input = x_input[1:]
    tempList_aapl.append(yhat)

# %%
history = model.fit(X_msft, y_msft, epochs=400, batch_size=150, verbose=0, validation_split = 0.10)

# %%
start = X_msft[X_msft.shape[0] - 13]
x_input = start
x_input = x_input.reshape((1, n_steps, n_features))

# %%
tempList_msft = []
for i in range(len(diff_test_msft)):
    x_input = x_input.reshape((1, n_steps, n_features))
    yhat = model.predict(x_input, verbose=0)
    x_input = np.append(x_input, yhat)
    x_input = x_input[1:]
    tempList_msft.append(yhat)

# %%
fig, ax = plt.subplots(2, 1, figsize=(18, 15))
ax[0].plot(diff_test_aapl, label='Actual Stock Price', linestyle='--')
ax[0].plot(diff_test_aapl.index, np.array(tempList_aapl).flatten(), linestyle='solid', label="Prediction")
ax[0].set_title('Predicted Stock Price-Apple')
ax[0].legend(loc='best')
ax[1].plot(diff_test_msft, label='Actual Stock Price', linestyle='--')
ax[1].plot(diff_test_msft.index, np.array(tempList_msft).flatten(), linestyle='solid', label="Prediction")
ax[1].set_title('Predicted Stock Price-Microsoft')
ax[1].legend(loc='best')

for ax in ax.flat:
    ax.set(xlabel='Date', ylabel='$')
plt.show()

# %% [markdown]
# # Resources:
# - Machine Learning for Financial Risk Management with Python
#     - https://learning.oreilly.com/library/view/machine-learning-for/9781492085249/
